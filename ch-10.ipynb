# %%
import sys

# %%
sys.version
# Out:
# '3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]'

# %%
# %%writefile Basic_.py
import streamlit as st
st.set_page_config(page_title=" BASICS ",page_icon=":",layout="centered")
st.header("Hello World !!")
# Out:
# Overwriting Basic_.py
